# %%
import pandas as pd

# %%
# Green areas (xlsx)
df_green = pd.read_excel('data/Share_of_green_areas_and_green_area_per_capita_in_cities_and_urban_areas_1990_-_2020.xlsx', sheet_name='Data')
# print(df_green.head(10))
print("Green areas columns:", df_green.columns)
print("Sample cities:", df_green['City Name'].unique()[:10])
print(len(df_green))
# Out:
# Green areas columns: Index(['Country or Territory Name', 'City Code', 'City Name', 'SDG Sub-Region',
#        'SDG Region', 'Average share of green area in city/urban area 1990 (%)',
#        'Average share of green area in city/ urban area 2000 (%)',
#        'Average share of green area in city/ urban area 2010 (%)',
#        'Average share of green area in city/ urban area 2020 (%)',
#        'Green area per capita 1990 (m2/person)',
#        'Green area per capita 2000 (m2/person)',
#        'Green area per capita 2010 (m2/person)',
#        'Green area per capita 2020 (m2/person)', 'Data Source', 'FootNote'],
#       dtype='object')
# Sample cities: ['Kabul' 'Herat' 'Mazar-e Sharif' 'Kandahar' 'Annaba' 'Blida' 'Qacentina'
#  'Chlef' 'Batna' 'Tiaret (Tihert)']
# 667

# %%
# Pollution (csv)
df_pollution = pd.read_csv('data/global_air_pollution_data.csv')
print("Pollution columns:", df_pollution.columns)
print("Sample cities:", df_pollution['city_name'].unique()[:10])
print(len(df_pollution))
# Out:
# Pollution columns: Index(['country_name', 'city_name', 'aqi_value', 'aqi_category',
#        'co_aqi_value\t', 'co_aqi_category', 'ozone_aqi_value',
#        'ozone_aqi_category', 'no2_aqi_value', 'no2_aqi_category',
#        'pm2.5_aqi_value', 'pm2.5_aqi_category'],
#       dtype='object')
# Sample cities: ['Praskoveya' 'Presidente Dutra' 'Priolo Gargallo' 'Przasnysz' 'Punaauia'
#  'Punta Gorda' 'Puttlingen' 'Puurs' 'Pyatigorsk' 'Qalyub']
# 23463

# %%
# Check cities (they will be foreign key)
common_cities = set(df_green['City Name']) & set(df_pollution['city_name'])
print(f"Number of common cities: {len(common_cities)}")
print(common_cities)
# Out:
# Number of common cities: 374
# {'Tepic', 'Toledo', 'Antananarivo', 'Hamburg', 'Minsk', 'Asyut', 'Mardan', 'Delhi', 'Madrid', 'Parakou', 'Wichita', 'Palermo', 'Tijuana', 'Lubin', 'Jabalpur', 'Sofia', 'Vilnius', 'Bekobod', 'Liberia', 'Bissau', 'Karlsruhe', 'Luena', 'Bologna', 'Lusaka', 'Agadir', 'Kabul', 'Austin', 'Maputo', 'Granada', 'Patna', 'Cochabamba', 'Pucallpa', 'Mashhad', 'Bukit Mertajam', 'Cartago', 'Thessaloniki', 'Leszno', 'Parbhani', 'Gouda', 'Baharampur', 'Puerto Vallarta', 'Jiddah', 'Bougouni', 'Ostrava', 'Terme', 'Nantes', 'Tianjin', 'Gorgan', 'Tampere', 'Bordeaux', 'Lilongwe', 'Monrovia', 'Rotterdam', 'Miami', 'Toulon', 'Qingdao', 'Kalisz', 'Istanbul', 'Kankan', 'Chengdu', 'Passos', nan, 'Bulawayo', 'Ahmadnagar', 'Berdsk', 'Salvador', 'Barretos', 'Kayseri', 'Amritsar', 'Maldonado', 'Wollongong', 'Nakuru', 'Haikou', 'Koriyama', 'Belmopan', 'Montevideo', 'Nampula', 'Bulancak', 'Iquitos', 'Kisangani', 'Ankara', 'San Pedro Sula', 'Ndola', 'Puebla', 'Horsens', 'Burgos', 'Trnava', 'Long Xuyen', 'Feira De Santana', 'Dire Dawa', 'Ludhiana', 'Odesa', 'Jalandhar', 'Dakar', 'Tours', 'Kolding', 'Campinas', 'Kerman', 'Nitra', 'Wilmington', 'Sasebo', 'Nha Trang', 'Hobart', 'Randers', 'Bharatpur', 'Angers', 'Taiping', 'Jalna', 'Raleigh', 'Seattle', 'Barranquilla', 'Belo Horizonte', 'Chimbote', 'Astrakhan', 'Niamey', 'Parma', 'Vinh', 'Medan', 'Christchurch', 'Islamabad', 'Koutiala', 'Torrelavega', 'Kuala Lumpur', 'Ouagadougou', 'Rabat', 'Juliaca', 'Aksaray', 'San Antonio', 'Norwich', 'Canberra', 'Nouakchott', 'Linz', 'Gaziantep', 'Sevilla', 'Belize', 'La Ceiba', 'Milwaukee', 'Kuching', 'Kassala', 'Sarajevo', 'San Diego', 'Dushanbe', 'Montgomery', 'Glasgow', 'Cirebon', 'Arusha', 'Irapuato', 'Huambo', 'Aizawl', 'Ljubljana', 'Herning', 'Reims', 'Odense', 'Tunis', 'Arica', 'Qujing', 'Palmerston', 'Hyderabad', 'Bremen', 'Bayamo', 'Charleston', 'Charlotte', 'Bhopal', 'Le Mans', 'Strasbourg', 'Buenos Aires', 'Tashkent', 'Auckland', 'Rosario', 'Turbat', 'Maxixe', 'Malanje', 'Santander', 'Dallas', 'Sopron', 'Mersin', 'Dublin', 'Johannesburg', 'Basel', 'Ordu', 'Miskolc', 'Vancouver', 'Malatya', 'Edinburgh', 'Darwin', 'Denizli', 'Tuzla', 'Sivas', 'Brno', 'Kayes', 'Surat', 'Temuco', 'Saltillo', 'Sikasso', 'Toronto', 'Fortaleza', 'Tarsus', 'Magdeburg', 'Chingola', 'Cleveland', 'Karaj', 'La Paz', 'Shiraz', 'San Juan', 'Kulim', 'Anand', 'Malaga', 'Sacramento', 'Hangzhou', 'Dhaka', 'Vejle', 'Santiago', 'Man', 'Calgary', 'Zagreb', 'Kandi', 'Baku', 'Mocuba', 'Larkana', 'Tacna', 'Riga', 'Bloemfontein', 'Santo Domingo', 'Gujranwala', 'Slagelse', 'Korhogo', 'Huancayo', 'Butembo', 'Banja Luka', 'Pokhara', 'Windhoek', 'Yerevan', 'El Paso', 'Petrolina', 'Cairns', 'Cape Town', 'Mbabane', 'Mazatenango', 'Omaha', 'Bunbury', 'Oxford', 'Bamako', 'Semarang', 'Lille', 'Savannah', 'Djougou', 'Trabzon', 'Saskatoon', 'Cuernavaca', 'Chaozhou', 'Celaya', 'Rize', 'Daska', 'Sydney', 'Santiago Del Estero', 'Morena', 'Zrenjanin', 'Metz', 'Messina', 'Limeira', 'Chicago', 'Freetown', 'Atlanta', 'Modena', 'Albuquerque', 'Blumenau', 'Rangpur', 'Bursa', 'Teresina', 'Valencia', 'Barcelona', 'San Marino', 'Burgas', 'Ziguinchor', 'Sanandaj', 'Peshawar', 'Gondar', 'Wellington', 'Bangalore', 'Salt Lake City', 'Gulu', 'Shahjahanpur', 'Kashan', 'London', 'Verona', 'Marseille', 'Baghdad', 'Karachi', 'Kitwe', 'Adelaide', 'Kenema', 'Moradabad', 'Bangui', 'Ardabil', 'Muswellbrook', 'Rancagua', 'Giresun', 'Villahermosa', 'Irbid', 'Tamale', 'Bengkulu', 'Sari', 'Camaguey', 'Herat', 'Amravati', 'Bouake', 'Bo', 'Quetzaltenango', 'Tokyo', 'Guarapari', 'Sioux Falls', 'Jhang', 'Faisalabad', 'Akita', 'Adana', 'Halmstad', 'Piura', 'Las Vegas', 'Ipoh', 'Hamilton', 'Legnica', 'Bratislava', 'Pekalongan', 'Philadelphia', 'Marsala', 'Dunedin', 'Sargodha', 'Asmara', 'Comayagua', 'Manila', 'Ceyhan', 'Nukus', 'Gaborone', 'Safaqis', 'Tanta', 'Melo', 'Valledupar', 'Sukkur', 'Rewa', 'Saurimo', 'Zhuji', 'Neiva', 'Yamoussoukro', 'Houston', 'Conakry', 'Zaragoza', 'Manaus', 'Monterrey', 'Tabriz', 'Nairobi', 'El Progreso', 'Aba', 'Tauranga ...
